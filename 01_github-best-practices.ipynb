# %% [markdown]
# # GitHub Best Practices

# %% [markdown]
# ___

# %% [markdown]
# ## Contents

# %% [markdown]
# 1. Basics of Git & GitHub
# 2. Branching
# 3. Committing
# 4. Pull Requests (PRs)
# 5. Merging & Cleaning Up
# 6. Handling Bugs in Branches
# 7. Rebasing vs Merging
# 8. Branch Protection Rules

# %% [markdown]
# ___

# %% [markdown]
# ## Branching

# %% [markdown]
# ### Default Policy

# %% [markdown]
# **Never push to main**

# %% [markdown]
# Default workflow should be:
# 1. Work on a branch
# 2. Open a PR
# 3. Merge
# 4. Delete the branch

# %% [markdown]
# ### Why Use Branches

# %% [markdown]
# * **Safety**: you don't break main
# * **Focus**: each branch is about one thing
# * **Teamwork**: many people can work on different features without affecting each other

# %% [markdown]
# #### When to open a new branch?

# %% [markdown]
# Start a new branch for every shippable piece.

# %% [markdown]
# ### How to Create and Switch

# %% [markdown]
# #### Create a new branch

# %% [markdown]
# ```
# git checkout -b feature/login
# ```

# %% [markdown]
# #### Switch between branches

# %% [markdown]
# **Switch to main**
# ```
# git checkout main
# ```

# %% [markdown]
# **Switch to feature/login**
# ```
# git checkout feature/login
# ```

# %% [markdown]
# ### Branch Naming Conventions

# %% [markdown]
# Keep it short, clear, lowercase, with dashes

# %% [markdown]
# Examples:
# * `feature/login-page`
# * `fix/profile-bug`

# %% [markdown]
# ___
